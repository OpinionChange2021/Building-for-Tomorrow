# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_paths = '/content/drive/MyDrive/aspects/top_aspects/'

# %%
# importing the module
import json
import ast
import re
topic = 'Books'
all_counts = {}

for word_index_year in range(2000,2019):
  # reading the data from the file
  with open(data_paths + 'aspects_cnt' + topic + str(word_index_year) + '.txt') as f:
      data = f.read()

  data = ast.literal_eval(data)
  all_counts[word_index_year] = data

# %%
years = len(all_counts.keys())
get_param = (years * 90) / 100

ymain = list(all_counts.keys())[0]

pattern = [] # ['ooooo','oiiiii','ooioo','iiioo','iiiii','ioioi','ioooo','oioio','ooioo','iiooo']
def printAllKLength(set, k):
    printAllKLengthRec(set, "", k)

def printAllKLengthRec(set, string, k):
    if len(string) == k:
        pattern.append(string)
        return
    for c in set:
        printAllKLengthRec(set, string + c, k)
    return

set1 = ['I','O']
printAllKLength(set1, years)

print(len(pattern))

years = str(int(years))
get_param = str(int(get_param))

print(years,get_param)

def unique_word(myStr):
  pt = myStr.count('I')
  if pt == 1:
    return True
  return False

def IV_word(myStr):
  pt = re.fullmatch(r'^I{'+ years +'}',myStr) #re.search("^a")
  if pt:
    return True
  return False

def dead(myStr):
  pt = re.fullmatch(r'^I{1,'+ get_param +'}(?:|O{2,})$',myStr) #re.search("^a")
  if pt:
    return True
  return False

def born(myStr):
  pt = re.fullmatch(r'^O{2,'+ get_param +'}(?:|I{1,})$',myStr) #re.search("^a")
  if pt:
    return True
  return False

words_years = {}
unique_words = {}

union_words = set([k for k, v in all_counts[ymain].items()])
for y in all_counts.keys():
    words = set([k for k, v in all_counts[y].items()])
    words_years[y] = words
    union_words = union_words.union(words)

# len(union_words)

fre_words_dict = {}
for w in list(union_words):
    freq_row = []
    for y in all_counts.keys():
        if w in words_years[y]:
            freq_row.append('I')
        else:
            freq_row.append('O')
    # print(w, 'freq row is ',freq_row)
    fre_words_dict[w] = ''.join(freq_row)

IVs = 0
Deads = 0
Borns = 0
Seasonal = 0
Unique_ = 0

vocab_IVs = []
vocab_Deads = []
vocab_Borns = []
vocab_Seasonal = []
vocab_Unique_ = []

pattern_IVs = []
pattern_Deads = []
pattern_Borns = []
pattern_Seasonal = []
pattern_Unique_ = []

for k, v in fre_words_dict.items():
    if IV_word(v):
        IVs += 1
        vocab_IVs.append(k)
        pattern_IVs.append(v)
    elif unique_word(v):
        Unique_ += 1
        vocab_Unique_.append(k)
        pattern_Unique_.append(v)
    elif born(v):
        Borns += 1
        vocab_Borns.append(k)
        pattern_Borns.append(v)
    elif dead(v):
        Deads += 1
        vocab_Deads.append(k)
        pattern_Deads.append(v)
    else:
        Seasonal += 1
        vocab_Seasonal.append(k)
        pattern_Seasonal.append(v)

print(IVs,Unique_, Deads, Borns, Seasonal)

rows = []
for y in all_counts.keys():
  words =  set([k for k,v in all_counts[y].items()])

  words_IVs = words.intersection(vocab_IVs)
  words_Deads = words.intersection(vocab_Deads)
  words_Borns = words.intersection(vocab_Borns)
  words_Seasonal = words.intersection(vocab_Seasonal)
  words_Unique_ = words.intersection(vocab_Unique_)


  IVs = len(words_IVs)
  Deads = len(words_Deads)
  Borns = len(words_Borns)
  Seasonal = len(words_Seasonal)
  Unique_ = len(words_Unique_)

  rows.append([str(y), IVs,Unique_, Deads, Borns, Seasonal])

dataset = pd.DataFrame(rows,columns= ['Year', 'IVs','Unique_', 'Deads', 'Borns', 'Seasonal'])
dataset.to_csv(topic + '_' + 'aspects_statistics.csv') 
dataset
# Out:
# 524288
# 19 17
# 1552 1367267 1176 345 205797
#     Year   IVs  Unique_  Deads  Borns  Seasonal
# 0   2000  1552    76939   1176      0     41611
# 1   2001  1552   100386   1176      0     49608
# 2   2002  1552    92971    253      2     49499
# 3   2003  1552   106252    151      4     53136
# 4   2004  1552   106779    126      5     53553
# 5   2005  1552   101370    120      8     51564
# 6   2006  1552    97834    116      8     50289
# 7   2007  1552    78081    114      8     44258
# 8   2008  1552    81613    111      8     45767
# 9   2009  1552    73244    108     10     42493
# 10  2010  1552    85987    106     10     47784
# 11  2011  1552    81030    104     12     46723
# 12  2012  1552    62100     97     12     39200
# 13  2013  1552    37140     82     13     27105
# 14  2014  1552    45606     68     17     30543
# 15  2015  1552    29530     54     18     21474
# 16  2016  1552    35909     38     49     24668
# 17  2017  1552    34053      0    345     23900
# 18  2018  1552    40443      0    345     27308

# %%
import operator
IVs = {k:v for k,v in all_counts[2000].items() if k in words_IVs}
# max(IVs , key=operator.itemgetter(1))
','.join(sorted(IVs, key=operator.itemgetter(1),reverse=True))
# Out:
# 'my only complaint,my favorite story,my only regret,my favorite book,my good friend,my favorite character,my only criticism,my favorite author,my favorite part,my only problem,my favorite thing,my favorite quote,excellent book,exciting book,excellent work,explain in detail,excellent source,excellent reference,exciting story,excellent read,excellent choice,excellent introduction,excellent addition,excellent guide,excellent resource,excellent job,extraordinary book,explain a lot,excellent novel,excellent story,excellent reading,excellent writer,exciting read,excellent example,excellent collection,excellent series,expect this book,exceptional job,excellent writing,excellent way,excellent information,excellent insight,excellent author,excellent description,excellent history,own mind,awesome book,own right,own faith,twist at the end,sweet story,sweet book,even more important,avid reader,even more interesting,funny book,current state,must read,outstanding job,pull no punch,suggest this book,much more interesting,superb job,just as good,must for anyone,much love,much fun,funny story,dull moment,human mind,super book,future work,just love it,full of wisdom,fun read,outstanding book,super hero,surprising twist,cute story,guess until the end,just as great,full of twist,funny way,it make I cry,strong character,it really help,it really make,it leave I want,strong woman,strongly recommend it,strongly recommend this book,strange thing,it be very easy,it make I feel,it really be,other work,story great,it remind I of,it make I think,stress the importance,it be definitely worth,it be well write,it make you think,it also help,strong female character,story as well,it make you want,it be well worth,it help I to,it easy for,it hard to put down,useful tip,user friendly,useful information,useful book,essential reading,as good as,ask the question,as important as,essential read,great book,great sense of humor,great sense,great resource,great guide,great read,great tip,great example,great insight,great work,great job,true believer,great buy,great writer,great time,great man,write very well,great thing,great picture,true story,great way,brilliant work,great success,great novel,truly enjoy this book,true to life,great character,great britain,great fan,great cookbook,great action,great love,great reference,great gift,great series,great idea,great addition,great plot,great little book,broken heart,great deal,great source,great value,great fun,true love,great stuff,great detail,great story,great help,brilliant book,great illustration,order this book,great place,great tool,great introduction,critical thinking,great study,great writing,true identity,great opportunity,great understanding,great storyteller,great photo,true meaning,great part,friend as well,previous work,great lesson,great adventure,great author,fresh air,great look,great information,true nature,true hero,true crime,great review,great service,great history,great quality,great price,great advice,great choice,great reading,great collection,great twist,try this one,fresh perspective,great literature,bright color,true life,brutal honesty,great chapter,great purchase,great strength,great tale,great depth,free time,great companion,great find,great art,great info,great product,great message,true gem,criminal justice,wrong way,great movie,great mystery,great ending,great start,great recipe,great inspiration,order the book,crystal clear,write so well,great reminder,truly enjoy read,great pleasure,creative way,great appreciation,great explanation,great surprise,great storyline,great coffee,great page,great food,great variety,great mix,great discussion,appreciate this book,open mind,spiritual warfare,spiritual life,spiritual journey,appreciate the fact,spiritual truth,special need,hope this book,good luck,good way,work very well,love this book,wonderful book,book as well,good history,book easy,complex character,you know what I,good choice,love the way,book be well,come to mind,love about this book,good job ...

# %%
rows = []
for y in all_counts.keys():
  words =  set([k for k,v in all_counts[y].items()])

  words_IVs = words.intersection(vocab_IVs)
  words_Deads = words.intersection(vocab_Deads)
  words_Borns = words.intersection(vocab_Borns)
  words_Seasonal = words.intersection(vocab_Seasonal)
  words_Unique_ = words.intersection(vocab_Unique_)

  flag = True
  n = 10
  l = 1
  IVs = {k:v for k,v in all_counts[y].items() if k in words_IVs and len(k) > n} #list(words_IVs)[0:5]
  IVs = list(sorted(IVs, key=operator.itemgetter(1),reverse=flag))[0:l]

  Deads = {k:v for k,v in all_counts[y].items() if k in words_Deads and len(k) > n} #list(words_Deads)[0:5]
  Deads = list(sorted(Deads, key=operator.itemgetter(1),reverse=flag))[0:l]

  Borns = {k:v for k,v in all_counts[y].items() if k in words_Borns and len(k) > n} #list(words_Borns)[0:5]
  Borns = list(sorted(Borns, key=operator.itemgetter(1),reverse=flag))[0:l]

  Seasonal = {k:v for k,v in all_counts[y].items() if k in words_Seasonal and len(k) > n} #list(words_Seasonal)[0:5]
  Seasonal = list(sorted(Seasonal, key=operator.itemgetter(1),reverse=flag))[0:l]

  Unique = {k:v for k,v in all_counts[y].items() if k in words_Unique_ and len(k) > n} #list(words_Unique_)[0:5]
  Unique = list(sorted(Unique, key=operator.itemgetter(1),reverse=flag))[0:l]

  rows.append([str(y), ','.join(IVs), ','.join(Unique), ','.join(Deads), ','.join(Borns), ','.join(Seasonal)])

dataset = pd.DataFrame(rows,columns= ['Year', 'IVs','Unique_', 'Deads', 'Borns', 'Seasonal'])
dataset.to_csv(topic + '_' + 'aspects_analysis'+ str(flag) + str(n) +'_' + str(l) +'.csv',index=None, encoding='utf-8-sig') 
dataset
# Out:
#     Year                    IVs                           Unique_  \
# 0   2000      my only complaint                       zz top song
# 1   2001       my favorite book                czar as a criminal
# 2   2002         my good friend                szasz very clearly
# 3   2003       my favorite part                       iz good buy
# 4   2004         my good friend                izu bettaa fallacy
# 5   2005  my favorite character                 jzsef feel desert
# 6   2006         my good friend                zz top style beard
# 7   2007  my favorite character                    ezra be cranky
# 8   2008         my good friend               czech golden cradle
# 9   2009      my only criticism                ezekiel revelation
# 10  2010      my only complaint                   ezekiel say how
# 11  2011     my favorite author              dziezynski make sure
# 12  2012     my favorite author                   azarian astound
# 13  2013     my favorite author               czarist restriction
# 14  2014       my favorite book                oz be surprisingly
# 15  2015       my favorite book                       az now hope
# 16  2016  my favorite character  czechloslavakia after the defeat
# 17  2017     my favorite author            mystery before the end
# 18  2018         my good friend                ezra fain need her
#
#                  Deads                 Borns                 Seasonal
# 0        my hectic day                           my personal favorite
# 1         lyrical gift                             my title suggest I
# 2      mystery for you         to help guide     my great grandfather
# 3     explode the myth         to help guide         my favorite poem
# 4        expect a book         to help guide      my favorite fantasy
# 5     excellent review         to help guide         my third attempt
# 6     excellent review         to help guide             eyed monster
# 7     excellent review         to help guide         my very favorite
# 8     excellent review         to help guide     eye to the injustice
# 9     excellent review      my honest review           my own destiny
# 10  excellent research      my honest review              my own idea
# 11    excellent review      my honest review            izzy struggle
# 12       expect a book      my honest review  my lifelong love affair
# 13  excellent research      my honest review            my next order
# 14       expect a book      my honest review       my initial thought
# 15  excellent research      my honest review       my favorite writer
# 16    excellent review      my honest review       my favorite writer
# 17                          my honest review          mystery of what
# 18                      mystery with a touch            izzy struggle

# %%
rows = []
for y in all_counts.keys():
  words =  set([k for k,v in all_counts[y].items()])

  words_IVs = words.intersection(vocab_IVs)
  words_Deads = words.intersection(vocab_Deads)
  words_Borns = words.intersection(vocab_Borns)
  words_Seasonal = words.intersection(vocab_Seasonal)
  words_Unique_ = words.intersection(vocab_Unique_)

  flag = False
  n = 10
  l = 1
  IVs = {k:v for k,v in all_counts[y].items() if k in words_IVs and len(k) > n} #list(words_IVs)[0:5]
  IVs = list(sorted(IVs, key=operator.itemgetter(1),reverse=flag))[0:l]

  Deads = {k:v for k,v in all_counts[y].items() if k in words_Deads and len(k) > n} #list(words_Deads)[0:5]
  Deads = list(sorted(Deads, key=operator.itemgetter(1),reverse=flag))[0:l]

  Borns = {k:v for k,v in all_counts[y].items() if k in words_Borns and len(k) > n} #list(words_Borns)[0:5]
  Borns = list(sorted(Borns, key=operator.itemgetter(1),reverse=flag))[0:l]

  Seasonal = {k:v for k,v in all_counts[y].items() if k in words_Seasonal and len(k) > n} #list(words_Seasonal)[0:5]
  Seasonal = list(sorted(Seasonal, key=operator.itemgetter(1),reverse=flag))[0:l]

  Unique = {k:v for k,v in all_counts[y].items() if k in words_Unique_ and len(k) > n} #list(words_Unique_)[0:5]
  Unique = list(sorted(Unique, key=operator.itemgetter(1),reverse=flag))[0:l]

  rows.append([str(y), ','.join(IVs), ','.join(Unique), ','.join(Deads), ','.join(Borns), ','.join(Seasonal)])

dataset = pd.DataFrame(rows,columns= ['Year', 'IVs','Unique_', 'Deads', 'Borns', 'Seasonal'])
dataset.to_csv(topic + '_' + 'aspects_analysis'+ str(flag) + str(n) +'_' + str(l) +'.csv',index=None, encoding='utf-8-sig') 
dataset
# Out:
#     Year                           IVs                       Unique_  \
# 0   2000                  a great book       a miraculous collection
# 1   2001                I always think              a complex coming
# 2   2002           a fascinating story              a modernist joke
# 3   2003                    great book          a marvelous resource
# 4   2004                  a great book            a fearful creature
# 5   2005               a vivid picture    t be as profound or timely
# 6   2006             I absolutely love     a successful defense case
# 7   2007                   a great job  I highly recommend this item
# 8   2008                I find it hard              s sudden absence
# 9   2009            I highly recommend              s prepare we for
# 10  2010            I highly recommend               I usually shirk
# 11  2011  I highly recommend this book   s fascinating autobiography
# 12  2012                  a great book            a mini masterpiece
# 13  2013                  a great book            a nice shower gift
# 14  2014                  a great read          a personal twist fun
# 15  2015                  a good laugh                I hope his new
# 16  2016             a wonderful story             s writing charm I
# 17  2017                   a good book                 I cal it fall
# 18  2018                 a great story                  great coffee
#
#                    Deads                    Borns  \
# 0        primary concern
# 1        a real treasure
# 2       a marvelous book        really enjoy they
# 3   I heartily recommend           I love it \n\n
# 4   I heartily recommend              I pre order
# 5   I heartily recommend           I love it \n\n
# 6   I heartily recommend           I love it \n\n
# 7          a great value       a perfect addition
# 8       s excellent book       a perfect addition
# 9       s excellent book           I love it \n\n
# 10  I heartily recommend           I love it \n\n
# 11        a helpful tool           I love it \n\n
# 12           a good case              I pre order
# 13        a helpful tool              I pre order
# 14       a real treasure              I pre order
# 15           a good gift           I love it \n\n
# 16  I heartily recommend       a perfect addition
# 17                        I consider myself bless
# 18                                 I love it \n\n
#
#                           Seasonal
# 0           political conservative
# 1                   s great writer
# 2                     a solid plot
# 3                 a terrific guide
# 4                  a certain power
# 5   I highly recommend this author
# 6                a public defender
# 7                      a dark road
# 8                    I guess we ll
# 9                     a good price
# 10               I think you would
# 11              a phenomenal story
# 12              easy to follow and
# 13                   a nice shower
# 14                     a true love
# 15                 a wonderful dog
# 16                       cute book
# 17                    a clear mind
# 18                a wonderful hero
