# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_paths = '/content/drive/MyDrive/aspects/top_aspects/'

# %%
# importing the module
import json
import ast
import re
topic = 'Sentiment'
word_index_year = '2013'
all_counts = {}

for word_index_year in range(2013,2021):
  # reading the data from the file
  with open(data_paths + 'aspects_cnt' + topic + str(word_index_year) + '.txt') as f:
      data = f.read()

  data = ast.literal_eval(data)
  all_counts[word_index_year] = data

# %%
years = len(all_counts.keys())
get_param = (years * 90) / 100

ymain = list(all_counts.keys())[0]

pattern = [] # ['ooooo','oiiiii','ooioo','iiioo','iiiii','ioioi','ioooo','oioio','ooioo','iiooo']
def printAllKLength(set, k):
    printAllKLengthRec(set, "", k)

def printAllKLengthRec(set, string, k):
    if len(string) == k:
        pattern.append(string)
        return
    for c in set:
        printAllKLengthRec(set, string + c, k)
    return

set1 = ['I','O']
printAllKLength(set1, years)

print(len(pattern))

years = str(int(years))
get_param = str(int(get_param))

print(years,get_param)

def unique_word(myStr):
  pt = myStr.count('I')
  if pt == 1:
    return True
  return False

def IV_word(myStr):
  pt = re.fullmatch(r'^I{'+ years +'}',myStr) #re.search("^a")
  if pt:
    return True
  return False

def dead(myStr):
  pt = re.fullmatch(r'^I{1,'+ get_param +'}(?:|O{2,})$',myStr) #re.search("^a")
  if pt:
    return True
  return False

def born(myStr):
  pt = re.fullmatch(r'^O{2,'+ get_param +'}(?:|I{1,})$',myStr) #re.search("^a")
  if pt:
    return True
  return False

words_years = {}
unique_words = {}

union_words = set([k for k, v in all_counts[ymain].items()])
for y in all_counts.keys():
    words = set([k for k, v in all_counts[y].items()])
    words_years[y] = words
    union_words = union_words.union(words)

# len(union_words)

fre_words_dict = {}
for w in list(union_words):
    freq_row = []
    for y in all_counts.keys():
        if w in words_years[y]:
            freq_row.append('I')
        else:
            freq_row.append('O')
    # print(w, 'freq row is ',freq_row)
    fre_words_dict[w] = ''.join(freq_row)

IVs = 0
Deads = 0
Borns = 0
Seasonal = 0
Unique_ = 0

vocab_IVs = []
vocab_Deads = []
vocab_Borns = []
vocab_Seasonal = []
vocab_Unique_ = []

pattern_IVs = []
pattern_Deads = []
pattern_Borns = []
pattern_Seasonal = []
pattern_Unique_ = []

for k, v in fre_words_dict.items():
    if IV_word(v):
        IVs += 1
        vocab_IVs.append(k)
        pattern_IVs.append(v)
    elif unique_word(v):
        Unique_ += 1
        vocab_Unique_.append(k)
        pattern_Unique_.append(v)
    elif born(v):
        Borns += 1
        vocab_Borns.append(k)
        pattern_Borns.append(v)
    elif dead(v):
        Deads += 1
        vocab_Deads.append(k)
        pattern_Deads.append(v)
    else:
        Seasonal += 1
        vocab_Seasonal.append(k)
        pattern_Seasonal.append(v)

print(IVs,Unique_, Deads, Borns, Seasonal)

rows = []
for y in all_counts.keys():
  words =  set([k for k,v in all_counts[y].items()])

  words_IVs = words.intersection(vocab_IVs)
  words_Deads = words.intersection(vocab_Deads)
  words_Borns = words.intersection(vocab_Borns)
  words_Seasonal = words.intersection(vocab_Seasonal)
  words_Unique_ = words.intersection(vocab_Unique_)


  IVs = len(words_IVs)
  Deads = len(words_Deads)
  Borns = len(words_Borns)
  Seasonal = len(words_Seasonal)
  Unique_ = len(words_Unique_)

  rows.append([str(y), IVs,Unique_, Deads, Borns, Seasonal])

dataset = pd.DataFrame(rows,columns= ['Year', 'IVs','Unique_', 'Deads', 'Borns', 'Seasonal'])
dataset.to_csv(topic + '_' + 'aspects_statistics.csv') 
dataset
# Out:
# 256
# 8 7
# 442 110629 403 792 12050
#    Year  IVs  Unique_  Deads  Borns  Seasonal
# 0  2013  442     9838    403      0      3509
# 1  2014  442    11572    403      0      4081
# 2  2015  442    11166    143     33      4195
# 3  2016  442    14206     87     70      4799
# 4  2017  442    15135     56    166      4878
# 5  2018  442    15773     32    349      4703
# 6  2019  442    16340      0    792      4316
# 7  2020  442    16599      0    792      3995

# %%
import operator
IVs = {k:v for k,v in all_counts[2013].items() if k in words_IVs}
# max(IVs , key=operator.itemgetter(1))
','.join(sorted(IVs, key=operator.itemgetter(1),reverse=True))
# Out:
# 'my good friend,my poor baby,even know what,hurt so bad,hurt so much,just realize I,fuck,fucking day,just want you,just tell I,just want my,just break my,just wish I,just want a,just see this,dumb ass,just say I,just ask I,hurt,dumb shit,cute,stupid shit,stress,it make I sad,stupid ass,starve,true,wrong person,cry,wrong side,cry so much,try so hard,great day,great,cry like a baby,wrong,love you so,so true,sorry,good friend,sooo bad,so sick of,good morning,so lucky,so bad,so sad,so tired of,soo bad,good idea,good mood,so bad 😭,good way,wow,good sleep,not good,go to hell,love you more,so tired,to bwe like,good time,you right,go to work,so annoying,love u so,so sorry,so bored,good day,good luck,you know you be,love he so,good night,so much pain,bored,confused,you know I be,cold weather,holy fuck,holy shit,sound so good,so much love,love it when,so jealous,sore throat,good ass,so hard,to go see,good thing,poor baby,so bad for,do that shit,love you too,good vibe,so beautiful,so cute,too much to ask for,do this shit,work,good,work right now,poor thing,so bad 😩,something wrong with,come true,bore,you know it be,so so sad,good people,so good,so happy,you love I,good girl,so much well,so bad 😭 😭,love she so,so pretty,good one,love of my,good 😩,so much fun,so beautiful 😭,only reason,know how much,know the feeling,amazing 😭,always get I,always make I,ll", ,sleep right now,miss you too,wish I never,fine ass,miss you so,miss you more,right,miss you already,sick,miss he so,miss u so,tired,give a fuck,miss she so,die,miss they so,will,thank,the only reason,the bad feeling,what happen,thank u so,shit,thank you so,the good day,the bad,the good,the good of,the bad thing,the good thing,thank you,this suck,the sad thing,the sad part,the same shit,the bad part,ugh,ugly ass,be pretty sure,be right,feel like shit,mean so much,be great,be horrible,be so sorry,be so lucky,be so confused,feel so good,help,be mad,be wrong,feel sick,be sick,tell I how,mean the world,really wish I,get well soon,feel so bad,be awful,need a hug,feel well,be so mad,get a headache,be nice,be too tired,feel so sick,be annoying,feel this way,be bored,be dead,be so jealous,feel sorry for,be tired,tell you how,be so upset,be so sad,be sad,never be this,be proud of,never think I,be so tired,be a bitch,be fine,be true,be in love,feel so ill,be amazing,be mad at,get tired of,be sorry,be so sweet,be good,be late for work,be so glad,teach I how,be so proud,be happy,be so hard,head hurt so,head hurt so bad,tell I why,really miss my,feel so bad for,be funny,be tired of,be at work,feel the need,be well,be in pain,really make I,dead ass,get sick,dead 😂,be bad,feel bad for,be so sick,be wrong with,be so proud of,rest in peace,be cute,be beautiful,be so excited,be cool,never be the,need a nap,well,be so nervous,ready for work,get ready for work,really,be so happy,be nice to,really think I,be so cute,never see I,feel well soon,get ready for,dead,be so beautiful,realize how much,be so damn,be stupid,scary movie,bad mood,have a headache,damn,take a break,laugh so hard,bad luck,have no idea,happy birthday,bad feeling,sad day,hate it when,bad attitude,fat ass,hate the fact,bad person,bad thing,have a feeling,bad 😭,bad 😩,sad,favorite song,bad dream,hard time,fall in love,late for work,bad part,have a problem,have no idea how,sad thing,sad part,bad bitch,same shit,damn time,favorite thing,bad day,fall asleep,hard work,fake ass,I be pretty sure,I feel your pain,I love you and,I think I be,I miss you 😭,I really hope,I be so sorry,I wish I have,I miss you too,I wish I be,I be so confused,a bad mood,I wish I could,I miss you so,I love you,I really want,I miss you more,I love you so,I know,I hate be,a good mood,I miss see,I think I have,I guess,I miss you already,I just feel,I just need,I never get,I just want,I know I know,, ,I think it be,I miss my baby,I just see,I mean,I always get,I love you more,I really wish,I just realize,I miss you,I feel so bad,I miss you guy,I think she be,I be sorry,I hate  ...

# %%
rows = []
for y in all_counts.keys():
  words =  set([k for k,v in all_counts[y].items()])

  words_IVs = words.intersection(vocab_IVs)
  words_Deads = words.intersection(vocab_Deads)
  words_Borns = words.intersection(vocab_Borns)
  words_Seasonal = words.intersection(vocab_Seasonal)
  words_Unique_ = words.intersection(vocab_Unique_)

  flag = True
  n = 10
  l = 1
  IVs = {k:v for k,v in all_counts[y].items() if k in words_IVs and len(k) > n} #list(words_IVs)[0:5]
  IVs = list(sorted(IVs, key=operator.itemgetter(1),reverse=flag))[0:l]

  Deads = {k:v for k,v in all_counts[y].items() if k in words_Deads and len(k) > n} #list(words_Deads)[0:5]
  Deads = list(sorted(Deads, key=operator.itemgetter(1),reverse=flag))[0:l]

  Borns = {k:v for k,v in all_counts[y].items() if k in words_Borns and len(k) > n} #list(words_Borns)[0:5]
  Borns = list(sorted(Borns, key=operator.itemgetter(1),reverse=flag))[0:l]

  Seasonal = {k:v for k,v in all_counts[y].items() if k in words_Seasonal and len(k) > n} #list(words_Seasonal)[0:5]
  Seasonal = list(sorted(Seasonal, key=operator.itemgetter(1),reverse=flag))[0:l]

  Unique = {k:v for k,v in all_counts[y].items() if k in words_Unique_ and len(k) > n} #list(words_Unique_)[0:5]
  Unique = list(sorted(Unique, key=operator.itemgetter(1),reverse=flag))[0:l]

  rows.append([str(y), ','.join(IVs), ','.join(Unique), ','.join(Deads), ','.join(Borns), ','.join(Seasonal)])

dataset = pd.DataFrame(rows,columns= ['Year', 'IVs','Unique_', 'Deads', 'Borns', 'Seasonal'])
dataset.to_csv(topic + '_' + 'aspects_analysis'+ str(flag) + str(n) +'_' + str(l) +'.csv',index=None, encoding='utf-8-sig') 
dataset
# Out:
#    Year             IVs          Unique_              Deads  \
# 0  2013  my good friend  i’m not excited     my mom tell my
# 1  2014  my good friend      ‼️ I always     my mom lose my
# 2  2015  my good friend    ‼️ damn light      my mom want I
# 3  2016  my good friend    Zzzz annoying      my mom want I
# 4  2017    my poor baby  I️ know exactly      just crack my
# 5  2018  my good friend   i️ never think  hurt like a bitch
# 6  2019  my good friend     I️ hate when
# 7  2020  my good friend     I️ drive mad
#
#                Borns             Seasonal
# 0                     my favorite movie 😭
# 1                            my mom say I
# 2        stay strong          my big fear
# 3        fucking sad        my poor heart
# 4  my favorite color       n’t wanna miss
# 5      n’t wanna see       n’t wanna miss
# 6        n’t like be        n’t know shit
# 7     n’t stop think  y’all remember when

# %%
rows = []
for y in all_counts.keys():
  words =  set([k for k,v in all_counts[y].items()])

  words_IVs = words.intersection(vocab_IVs)
  words_Deads = words.intersection(vocab_Deads)
  words_Borns = words.intersection(vocab_Borns)
  words_Seasonal = words.intersection(vocab_Seasonal)
  words_Unique_ = words.intersection(vocab_Unique_)

  flag = False
  n = 10
  l = 1
  IVs = {k:v for k,v in all_counts[y].items() if k in words_IVs and len(k) > n} #list(words_IVs)[0:5]
  IVs = list(IVs)[0:l]

  Deads = {k:v for k,v in all_counts[y].items() if k in words_Deads and len(k) > n} #list(words_Deads)[0:5]
  Deads = list(Deads)[0:l]

  Borns = {k:v for k,v in all_counts[y].items() if k in words_Borns and len(k) > n} #list(words_Borns)[0:5]
  Borns = list(Borns)[0:l]

  Seasonal = {k:v for k,v in all_counts[y].items() if k in words_Seasonal and len(k) > n} #list(words_Seasonal)[0:5]
  Seasonal = list(Seasonal)[0:l]

  Unique = {k:v for k,v in all_counts[y].items() if k in words_Unique_ and len(k) > n} #list(words_Unique_)[0:5]
  Unique = list(Unique)[0:l]

  rows.append([str(y), ','.join(IVs), ','.join(Unique), ','.join(Deads), ','.join(Borns), ','.join(Seasonal)])

dataset = pd.DataFrame(rows,columns= ['Year', 'IVs','Unique_', 'Deads', 'Borns', 'Seasonal'])
dataset.to_csv(topic + '_' + 'aspects_analysis'+ str(flag) + str(n) +'_' + str(l) +'.csv',index=None, encoding='utf-8-sig') 
dataset
# Out:
#    Year             IVs                             Unique_  \
# 0  2013  be pretty sure                 boi extremely happy
# 1  2014  I wish I could                       then help you
# 2  2015  I wish I could                      never happen I
# 3  2016    I think I be  @VixxWickedKitty just when I think
# 4  2017     fall asleep                    shut they pretty
# 5  2018     I just want                      holy shit fuck
# 6  2019  happy birthday                      the bad player
# 7  2020   I be so tired                     believe the UFC
#
#                  Deads            Borns            Seasonal
# 0         the bad mood                          I feel ya 😭
# 1          stupid fuck                          so true tho
# 2  work in the morning  I miss you baby        I think it ’
# 3        just crack my      a good show  we definitely have
# 4          great start      so cute 😭 😭      I be exhausted
# 5       life right now      ’m so bored     I know there be
# 6                           I know it ’        good picture
# 7                           be n’t work         other bitch
